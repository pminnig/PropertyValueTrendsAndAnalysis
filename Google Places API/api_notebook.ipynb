# %%
# Importing Dependencies

import requests
import json
import pprint
import pandas as pd
from pandas import json_normalize
import time
from key import API_KEY

# %%
# Establishing base variables and utilizing loops to call for data on multiple coordinates and storing that information in a list

data = []
places_url = f'https://maps.googleapis.com/maps/api/place/nearbysearch/json?&key={API_KEY}'

coords = ["41.927826, -87.652016", "40.38, -75.77", "40.6239, -75.3937", "40.1769, -75.1020", "39.9683, -75.1750", "40.4737, -79.9612"]
keywords = ["food", "establishments", "bars", "meal_takeaway", "point_of_interest", "establishment", "resturant", "cafe"]

for i in coords:
    params = {
            "location": i,
            "radius": 50000,
            "keyword": keywords
    }

    response = requests.get(places_url, params=params).json()
    next_page_token =  response['next_page_token']

    page = 1
    
# Creating a nested while loop to repedietely utilize the next page token found in the json to gather more data entries with a limit of < 10 pages

    while page < 10:
        print(f'Appending page {page}')
        page +=1
        params = {
           "location": i,
           "radius": 50000,
           "keyword": keywords,
           "pagetoken": next_page_token
       }

        time.sleep(1)

        response = requests.get(places_url, params=params).json()
        data.append(response)
# Out:
# Appending page 1
# Appending page 2
# Appending page 3
# Appending page 4
# Appending page 5
# Appending page 6
# Appending page 7
# Appending page 8
# Appending page 9
# Appending page 1
# Appending page 2
# Appending page 3
# Appending page 4
# Appending page 5
# Appending page 6
# Appending page 7
# Appending page 8
# Appending page 9
# Appending page 1
# Appending page 2
# Appending page 3
# Appending page 4
# Appending page 5
# Appending page 6
# Appending page 7
# Appending page 8
# Appending page 9
# Appending page 1
# Appending page 2
# Appending page 3
# Appending page 4
# Appending page 5
# Appending page 6
# Appending page 7
# Appending page 8
# Appending page 9
# Appending page 1
# Appending page 2
# Appending page 3
# Appending page 4
# Appending page 5
# Appending page 6
# Appending page 7
# Appending page 8
# Appending page 9
# Appending page 1
# Appending page 2
# Appending page 3
# Appending page 4
# Appending page 5
# Appending page 6
# Appending page 7
# Appending page 8
# Appending page 9

# %%
# Taking json data from data variable and storing each page of json in corresponding lists #
# This line can be used to print out all data entries...pprint.pprint(data)

chicago_data = []
chicago_data.append(data[0:9])
#------------------------------------------------------------------------------------------#
oley_data = []
oley_data.append(data[10:19])
#------------------------------------------------------------------------------------------#
beth_data = []
beth_data.append(data[20:29])
#------------------------------------------------------------------------------------------#
horsham_data = []
horsham_data.append(data[30:39])
#------------------------------------------------------------------------------------------#
north_philly_data = []
north_philly_data.append(data[40:49])
#------------------------------------------------------------------------------------------#
pitts_data = []
pitts_data.append(data[50:59])
# Out:
# [{'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'},
#  {'html_attributions': [],
#   'next_page_token': 'Aap_uECQBbXRzD-KQhgLy8Hr8Bzt6GXwi04WXszhlcg-fwieBGd_zzheGBKWo-U55VNLhKu-CVxIVp1nvTs-PxYzhljGGNphcNKYDsHXIZZmJ1aWwzC9-z12a5zqcdw61voiUydRIetsshsNyB3knOfd2OSoDb1ZS_10Z1lwKg0huLPO0b61J3oiH1rlvgZAanQGDDnujWkdkduEt9Cfg9kF6BIUEKdWy3wyUnZFVUV4qEgvEJPt5eEM0smL2Enqy9UC9ECKplHv-L0i0Lz4XCpLgMcjeHabJDyjLErXDg1_JI3lmhNPkzQnIXg7eB-8L6MokbeBjP5dSjVNdnoyZDMYWQ3E_nBh0mVYDJzHEtCn2wu0Lx9Td5GxqbwFYQM0TjikGfhV7mMuKz8_2aFuN-uKx0AnlCJ6QUjauNiMYCgkzsvRj0pTeTEdSyxd3G4aORZXELbKsnECUcnEwvRRX44cIzw-YcoQ4Qku6_pBZ0pjiP-ufXOHY6CWM1-g04XpN-n5BGPT95PBdgU0-tBuN12fYH-AoNLsDjhXLWZOJEX0dozwjIUy3sBLEsjPO-0FGgi7xZafU5nzlR9IFZrJZBgeM1279nnODZx-pRyw17g6VipfXqcjtweDZI_ZolTekqfjMvpW0GzmWQ',
#   'results': [{'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 41.9221964,
#                                          'lng': -87.64458289999999},
#                             'viewport': {'northeast': {'lat': 41.92361212989272,
#                                                        'lng': -87.64314687010726},
#                                          'southwest': {'lat': 41.92091247010728,
#                                                        'lng': -87.64584652989271}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': "Xi'an Dynasty Cuisine 西安食代 (Lincoln Park)",
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 3024,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/117040788747065101824">Jianfeng '
#                                                  'Du</a>'],
#                            'photo_reference': 'Aap_uEDgdW1iSfkgPcgxepJg8jD3eo8cl0MAu4q7fv7B6ZXMH_6R_ATWKKlIhjF-Z-IJTwPr0HI24YcJViEO-wA2w4bZWDvam_baUZnjYlzoaTFy56mrsf6SfDN4mZjIa_ftO5rKyOQQodlK3kIg9RsPEnPas6vqWsrXxDG2o6CI6yaLXAHH',
#                            'width': 4032}],
#                'place_id': 'ChIJb8C5k2jTD4gR7qwYAfywnPY',
#                'plus_code': {'compound_code': 'W9C4+V5 Chicago, Illinois',
#                              'global_code': '86HJW9C4+V5'},
#                'price_level': 1,
#                'rating': 4.7,
#                'reference': 'ChIJb8C5k2jTD4gR7qwYAfywnPY',
#                'scope': 'GOOGLE',
#                'types': ['restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 124,
#                'vicinity': '2218 N Lincoln Ave, Chicago'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 41.9237584, 'lng': -87.6686678},
#                             'viewport': {'northeast': {'lat': 41.92520882989272,
#                                                        'lng': -87.66728852010728},
#                                          'southwest': {'lat': 41.92250917010728,
#                                                        'lng': -87.66998817989273}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': "Wendy's",
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 720,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/114473675868787784396">Wendy&#39;s</a>'],
#                            'photo_reference': 'Aap_uEAUVxJx2bLi-rTutTmXvrmEnoPyagKqvlrfdrMNKAzsCrZ7HyfLaVgFyRXfbI73zHzqXLI-i_lhgT1fYvBK5efW3YcJXu8G2DshuNUTVBefFubAVxDf8WUvQDx8aJN7BG2bAq4yK7Ea6O8i_Yx58InNzIfT0kJYpO6BdNlqTbMfSlUS',
#                            'width': 720}],
#                'place_id': 'ChIJ_24whu_SD4gRHteCQLI3ErE',
#                'plus_code': {'compound_code': 'W8FJ+GG Chicago, Illinois',
#                              'global_code': '86HJW8FJ+GG'},
#                'price_level': 1,
#                'rating': 3.9,
#                'reference': 'ChIJ_24whu_SD4gRHteCQLI3ErE',
#                'scope': 'GOOGLE',
#                'types': ['restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 1442,
#                'vicinity': '2312 N Ashland Ave, Chicago'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 41.9175694, 'lng': -87.648662},
#                             'viewport': {'northeast': {'lat': 41.91894427989272,
#                                                        'lng': -87.64722792010728},
#                                          'southwest': {'lat': 41.91624462010728,
#                                                        'lng': -87.64992757989273}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': 'Summer House Santa Monica',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 2400,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/110633615553284940915">A '
#                                                  'Google User</a>'],
#                            'photo_reference': 'Aap_uEAMr8JJP-5ybfOgFIwIC-E7pc3WNG8Sn-cOkAlAeI4zhLjyeJHAOmPRT96lkSpft89UtMGXmAHf3qkuOgkVLBjVHmfeR-8KMLbuZ7d70Qkn9GxA-vtfRZhs0VilDbU2MLdT5C_9EuBlAu3eNh0slqJDMaiR8_F067N_sMze4QWXM97j',
#                            'width': 1600}],
#                'place_id': 'ChIJxYDpLhjTD4gRXbOM_K_279E',
#                'plus_code': {'compound_code': 'W992+2G Chicago, Illinois',
#                              'global_code': '86HJW992+2G'},
#                'price_level': 2,
#                'rating': 4.4,
#                'reference': 'ChIJxYDpLhjTD4gRXbOM_K_279E',
#                'scope': 'GOOGLE',
#                'types': ['bakery',
#                          'bar',
#                          'restaurant',
#                          'food',
#                          'point_of_interest',
#                          'store',
#                          'establishment'],
#                'user_ratings_total': 1977,
#                'vicinity': '1954 N Halsted St, Chicago'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 41.9228107, 'lng': -87.6448656},
#                             'viewport': {'northeast': {'lat': 41.92411717989272,
#                                                        'lng': -87.64356087010727},
#                                          'southwest': {'lat': 41.92141752010728,
#                                                        'lng': -87.64626052989271}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': 'Kizami Sushi',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 4480,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/113286659829013150152">A '
#                                                  'Google User</a>'],
#                            'photo_reference': 'Aap_uEDwzskjw2TyuaZDjt021ONBKX1y3uLDqxS2Dv6gsd7vdr7x9fTiJkDVo0sXp-xzIh4Isg6CzI4YllpXr8ZH5p2zVwkBcHIiRwoBjcPvzwGPkEov6E48LIq8sCH8vpR6inX8gCD5z8vNLy4jGMRaTbvKgEn3iNuwAUWqLsuylqqLeHKx',
#                            'width': 6720}],
#                'place_id': 'ChIJa1ytdeDTD4gR9zKvfdUOkbE',
#                'plus_code': {'compound_code': 'W9F4+43 Chicago, Illinois',
#                              'global_code': '86HJW9F4+43'},
#                'price_level': 2,
#                'rating': 4.8,
#                'reference': 'ChIJa1ytdeDTD4gR9zKvfdUOkbE',
#                'scope': 'GOOGLE',
#                'types': ['restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 89,
#                'vicinity': '2235 N Lincoln Ave, Chicago'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 41.9267452, 'lng': -87.650976},
#                             'viewport': {'northeast': {'lat': 41.92816792989272,
#                                                        'lng': -87.64954227010728},
#                                          'southwest': {'lat': 41.92546827010727,
#                                                        'lng': -87.65224192989271}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': 'Dog Haus',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 2304,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/117254188092758896131">Corlyn '
#                                                  'Jacobsen</a>'],
#                            'photo_reference': 'Aap_uEDT-jpR4z-bluE1l2uqgwS_oTudsO_mBNwpc8-7YUglGaNWMgZgzbxvAf0HuhtX-dN0vrVlItNu5xweF4PjC3IrAMjNd06EXc6piyxO-utZ4EW9PCeWgNthPlFx-dTEiABJBbtXyx332Pf9vAoePpnn1vLaponi8Jxlm8F9wa3F80Ql',
#                            'width': 4096}],
#                'place_id': 'ChIJq6q64ATTD4gRRl1DJ-eSfqM',
#                'plus_code': {'compound_code': 'W8GX+MJ Chicago, Illinois',
#                              'global_code': '86HJW8GX+MJ'},
#                'price_level': 2,
#                'rating': 4.4,
#                'reference': 'ChIJq6q64ATTD4gRRl1DJ-eSfqM',
#                'scope': 'GOOGLE',
#                'types': ['meal_takeaway',
#                          'bar',
#                          'restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 625,
#                'vicinity': '2464 N Lincoln Ave, Chicago'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 41.92178800000001,
#                                          'lng': -87.6642973},
#                             'viewport': {'northeast': {'lat': 41.92307632989272,
#                                                        'lng': -87.66302722010728},
#                                          'southwest': {'lat': 41.92037667010728,
#                                                        'lng': -87.66572687989273}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/bar_pinlet',
#                'name': "Beck's Chicago",
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 1620,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/104336273648696285012">A '
#                                                  'Google User</a>'],
#                            'photo_reference': 'Aap_uECQ2HMytJu5hAKKohI0L7dRq1_xFHnkgCFGKoA73lC6qVMXtevZYm95AJ7LR24dIPpsMBhfgrhUgX3WBMUSjXmhLWmTy5SyTF4PJNswgsBvglaZQh2Wsbw5JydopPVEAanFRBO2q_46nHngiXwQoeMhB4CEPKsL0100Z615ceWOXDl8',
#                            'width': 2880}],
#                'place_id': 'ChIJi5pb_iXTD4gRMnn3MQXpkxQ',
#                'plus_code': {'compound_code': 'W8CP+P7 Chicago, Illinois',
#                              'global_code': '86HJW8CP+P7'},
#                'rating': 4.7,
#                'reference': 'ChIJi5pb_iXTD4gRMnn3MQXpkxQ',
#                'scope': 'GOOGLE',
#                'types': ['bar',
#                          'restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 118,
#                'vicinity': '2201 N Clybourn Ave, Chicago'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 41.9264445, 'lng': -87.6411894},
#                             'viewport': {'northeast': {'lat': 41.92782227989272,
#                                                        'lng': -87.63975687010728},
#                                          'southwest': {'lat': 41.92512262010727,
#                                                        'lng': -87.64245652989273}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': 'The Pasta Bowl - Lincoln Park',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 640,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/116659738337856938999">A '
#                                                  'Google User</a>'],
#                            'photo_reference': 'Aap_uEBFNF-_LgIrsPcdb-UCxA1HucmnqHwRApAYBOvPh9ahBv98OqhSxEFSav8uFwwFQZSiTj7bj9WbWw_PltscJF7fTA9JPrFxCOqgiVFBsGowBiWDoHyL7C2JrnacPWddHVZn6N2aAof01c7GJPrhtJ2xPWRRjp2yVeBr4f7a6QoXgcGf',
#                            'width': 640}],
#                'place_id': 'ChIJOSYpmA3TD4gR7FeUKvZJ-Gc',
#                'plus_code': {'compound_code': 'W9G5+HG Chicago, Illinois',
#                              'global_code': '86HJW9G5+HG'},
#                'price_level': 2,
#                'rating': 4.5,
#                'reference': 'ChIJOSYpmA3TD4gR7FeUKvZJ-Gc',
#                'scope': 'GOOGLE',
#                'types': ['meal_delivery',
#                          'meal_takeaway',
#                          'bar',
#                          'restaurant',
#                          'food',
#                          'point_of_interest',
#                          'store',
#                          'establishment'],
#                'user_ratings_total': 834,
#                'vicinity': '2434 N Clark St, Chicago'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 41.92944199999999,
#                                          'lng': -87.64301499999999},
#                             'viewport': {'northeast': {'lat': 41.93082612989272,
#                                                        'lng': -87.64155752010727},
#                                          'southwest': {'lat': 41.92812647010728,
#                                                        'lng': -87.64425717989272}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': 'Del Seoul',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 2988,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/100337063123205043623">Pablo '
#                                                  'Moran Sr.</a>'],
#                            'photo_reference': 'Aap_uEBLTlDIAoAPKhRUOrdC2nv_tD5AELiCdAwTBsAxAcpjfZs83CHoheogvh_NhHXE7JSbAOloyXSrLIZDRSHoykZaFdoAMgZOID4Od0_Fro_SWWunW-nnggnHstzm1GDNS87sCT5pCFdOwoShObLNtDDUy9miDlQBeTASdOYgfp5NVv7L',
#                            'width': 5312}],
#                'place_id': 'ChIJmcIAGwzTD4gRC37nKNYVECg',
#                'plus_code': {'compound_code': 'W9H4+QQ Chicago, Illinois',
#                              'global_code': '86HJW9H4+QQ'},
#                'price_level': 1,
#                'rating': 4.6,
#                'reference': 'ChIJmcIAGwzTD4gRC37nKNYVECg',
#                'scope': 'GOOGLE',
#                'types': ['restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 1481,
#                'vicinity': '2568 N Clark St, Chicago'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 41.94000630000001,
#                                          'lng': -87.6554433},
#                             'viewport': {'northeast': {'lat': 41.94135612989272,
#                                                        'lng': -87.65409347010728},
#                                          'southwest': {'lat': 41.93865647010728,
#                                                        'lng': -87.65679312989273}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': "BIG & little's Restaurant",
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 1280,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/101360926350055614909">Steve '
#                                                  'Augle</a>'],
#                            'photo_reference': 'Aap_uEBDdTHmPfOC2a22EhdR-_7Rb2orFSPmtzQKJ5FR9TFB4ye1jhczHnIhPDJSP2IognIkzZqnibSSNkpc0YkRLhJwal1SGh5rNDSfrfNNdpB_QgXfP6DoTe84zCeuBbeAqepMtUuTI5IHQQiVZTUpX5ZtOesGU569UPrWzhVxWnc4PnUP',
#                            'width': 1920}],
#                'place_id': 'ChIJb_pZgqvTD4gRHJ7pZ8LNyUA',
#                'plus_code': {'compound_code': 'W8RV+2R Chicago, Illinois',
#                              'global_code': '86HJW8RV+2R'},
#                'price_level': 1,
#                'rating': 4.4,
#                'reference': 'ChIJb_pZgqvTD4gRHJ7pZ8LNyUA',
#                'scope': 'GOOGLE',
#                'types': ['meal_delivery',
#                          'meal_takeaway',
#                          'restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 860,
#                'vicinity': '1034 W Belmont Ave, Chicago'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 41.9184528, 'lng': -87.6535361},
#                             'viewport': {'northeast': {'lat': 41.91985982989272,
#                                                        'lng': -87.65216687010728},
#                                          'southwest': {'lat': 41.91716017010728,
#                                                        'lng': -87.65486652989273}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': 'Sai Café',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 1908,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/117859505911778402801">Maya '
#                                                  'Rotman-Zaid</a>'],
#                            'photo_reference': 'Aap_uEBkh6C6ijpQsN3OwGB2VRbWFOWtpmaB-IFA269n_IsA27aT3j3Oq5XW89XcJwzArEOxHinGQQgzH0AJUjXVP90lGK5dW04hXI8E-0dG3GEJNLDMwgCa-OTBZhHCpjDy96sdz0ZmSlUalgb7ssCak54JQfBLumO_MDIthwY-GHe89-wG',
#                            'width': 4032}],
#                'place_id': 'ChIJzTvW0x7TD4gRqt6CDlKlLcc',
#                'plus_code': {'compound_code': 'W89W+9H Chicago, Illinois',
#                              'global_code': '86HJW89W+9H'},
#                'price_level': 2,
#                'rating': 4.6,
#                'reference': 'ChIJzTvW0x7TD4gRqt6CDlKlLcc',
#                'scope': 'GOOGLE',
#                'types': ['restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 137,
#                'vicinity': '2010 N Sheffield Ave, Chicago'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 41.8934295, 'lng': -87.6314147},
#                             'viewport': {'northeast': {'lat': 41.89467977989272,
#                                                        'lng': -87.62993797010726},
#                                          'southwest': {'lat': 41.89198012010728,
#                                                        'lng': -87.63263762989271}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': "Portillo's Hot Dogs",
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 1080,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/101102105371499942043">Ray '
#                                                  'Jeong</a>'],
#                            'photo_reference': 'Aap_uEAuhakJHLW07DChphM_X_df2zfByKvTTcFoERwQeqRiZzSDI8EzYnwdjMXQIiZw9zOsWtW9941xKd_AQCbZnA9Ko0GszVK-noREXI7foaU62Sn_lEqZZf-Ak62hSF6M2Izy5VIzFeMFRMOJzW8e5pmgx7bX2hBRmttzsxnPZJzldarq',
#                            'width': 1920}],
#                'place_id': 'ChIJf_CED7MsDogR72PLB04AlFA',
#                'plus_code': {'compound_code': 'V9V9+9C Chicago, Illinois',
#                              'global_code': '86HJV9V9+9C'},
#                'price_level': 1,
#                'rating': 4.4,
#                'reference': 'ChIJf_CED7MsDogR72PLB04AlFA',
#                'scope': 'GOOGLE',
#                'types': ['meal_takeaway',
#                          'restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 15736,
#                'vicinity': '100 W Ontario St, Chicago'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 41.9139595, 'lng': -87.6485251},
#                             'viewport': {'northeast': {'lat': 41.91531207989271,
#                                                        'lng': -87.64709237010727},
#                                          'southwest': {'lat': 41.91261242010727,
#                                                        'lng': -87.64979202989272}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': 'Willow Room',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 2930,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/107973160747663820850">Willow '
#                                                  'Room</a>'],
#                            'photo_reference': 'Aap_uEC_MN10JbCIGoACj4fZ4fzgGrEZi9Bk9ikwMDXJhqOR6IrzkdECDaMtpBJ3KCk9AvvdC4sdlI6CzrzJFZiqj3CbFR517eCjsfd20ZFZLQFWpcJKwZZhPt7hxrO--jw5Lw7bSGYsSaz8G-O3G7qD9CRilQlEhOROYxZa1HjPeCFc8W7Y',
#                            'width': 5746}],
#                'place_id': 'ChIJ9Zj5yyLTD4gRCAVsic2iQfY',
#                'plus_code': {'compound_code': 'W972+HH Chicago, Illinois',
#                              'global_code': '86HJW972+HH'},
#                'price_level': 2,
#                'rating': 4.6,
#                'reference': 'ChIJ9Zj5yyLTD4gRCAVsic2iQfY',
#                'scope': 'GOOGLE',
#                'types': ['restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 427,
#                'vicinity': '1800 N Halsted St, Chicago'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 41.9329785, 'lng': -87.6442825},
#                             'viewport': {'northeast': {'lat': 41.93424007989272,
#                                                        'lng': -87.64293057010728},
#                                          'southwest': {'lat': 41.93154042010728,
#                                                        'lng': -87.64563022989272}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': 'Stand-Up Burgers',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 3024,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/117271048978654199971">Nick '
#                                                  'Altmann</a>'],
#                            'photo_reference': 'Aap_uEDarcSVbuqyXo6j_I1j8dZk8-5j2EYJ8wYyiEIh8BQgy8TYxAc3qZJ4Nsz1x8qRMj8qsnNHK4UCBCRlvzcDhRhEHmEGqR-Wh8Ag4xAIcp7g_VJSyHvdC09gz2Luxxx9om0nY0iU9vLLg5QqQ9yM4qsyfiG70BQl-ZjQG3tK2U0eSKZF',
#                            'width': 4032}],
#                'place_id': 'ChIJ-d0aoAnTD4gRO9P8A_hT4fk',
#                'plus_code': {'compound_code': 'W9M4+57 Chicago, Illinois',
#                              'global_code': '86HJW9M4+57'},
#                'price_level': 2,
#                'rating': 4.4,
#                'reference': 'ChIJ-d0aoAnTD4gRO9P8A_hT4fk',
#                'scope': 'GOOGLE',
#                'types': ['restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 340,
#                'vicinity': '614 W Diversey Pkwy, Chicago'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 41.9221306, 'lng': -87.6443737},
#                             'viewport': {'northeast': {'lat': 41.92366987989272,
#                                                        'lng': -87.64319697010728},
#                                          'southwest': {'lat': 41.92097022010728,
#                                                        'lng': -87.64589662989272}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': "Bacino's of Lincoln Park",
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 3840,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/104094100180463855486">A '
#                                                  'Google User</a>'],
#                            'photo_reference': 'Aap_uED_c1SeuvtSFQue2_szf7eZIIc03Xjvaqpe0jji2cwEMP42hXr15KPR8i84ZgETuaBy7jkveZHRUSbQ532BMRDNyQW_9vLg5pzNbSy6s7TPKSk1oyacz-1JJoryU2OiELoadZg5ovuKlkGWkUMkgBx5GO3aBziiiuBjHF48caCmYnsG',
#                            'width': 5760}],
#                'place_id': 'ChIJm93Wl23TD4gRrSWlWSTrwNw',
#                'plus_code': {'compound_code': 'W9C4+V7 Chicago, Illinois',
#                              'global_code': '86HJW9C4+V7'},
#                'rating': 4.5,
#                'reference': 'ChIJm93Wl23TD4gRrSWlWSTrwNw',
#                'scope': 'GOOGLE',
#                'types': ['restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 345,
#                'vicinity': '2204 N Lincoln Ave, Chicago'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 41.9179056, 'lng': -87.6486389},
#                             'viewport': {'northeast': {'lat': 41.91925542989273,
#                                                        'lng': -87.64728907010728},
#                                          'southwest': {'lat': 41.91655577010728,
#                                                        'lng': -87.64998872989271}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': 'Pasta Palazzo',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 3036,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/110589511314575662579">Chandler '
#                                                  'Conn</a>'],
#                            'photo_reference': 'Aap_uECl89MlicdL0BuTRqxDjR7EMXcO6-Dpy6rc9mOJd6TsBDQhc1cvrHun9U5muVM3u4W0ZzjE3LXlDT86Lxg_UC4NTZ8Y3QLDxj86H03rHQ8rUM7UiDw1SPP4WUiEfF6grls2Q-WsKEzP4WmO85ScDkZTc4_IeXif9tHZPyJQTbbXYHVA',
#                            'width': 4048}],
#                'place_id': 'ChIJE6PeKBjTD4gRDkbEbayEwE0',
#                'plus_code': {'compound_code': 'W992+5G Chicago, Illinois',
#                              'global_code': '86HJW992+5G'},
#                'price_level': 1,
#                'rating': 4.6,
#                'reference': 'ChIJE6PeKBjTD4gRDkbEbayEwE0',
#                'scope': 'GOOGLE',
#                'types': ['restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 544,
#                'vicinity': '1966 N Halsted St, Chicago'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 41.9110489, 'lng': -87.6327457},
#                             'viewport': {'northeast': {'lat': 41.91244992989272,
#                                                        'lng': -87.63139707010728},
#                                          'southwest': {'lat': 41.90975027010727,
#                                                        'lng': -87.63409672989273}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': 'Peking Chinese Food',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 1836,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/108141978885170924488">amadeo '
#                                                  'rodriguez</a>'],
#                            'photo_reference': 'Aap_uEAZOE4uj7wvq3s0df41RlYtWAIe8Mstltjd3nc0CO_lV4ihvx79eCFtlrspYB4NecD6JTbCELYfwH2O6eoIS-xrG2UYDKQpsP1jYbttwrhlIrJp7S74fsoiWctE1H3IVqNoGBMjCvceLw3rDeFCg4XBV8O3Hykxx069yZRF5bkeJxQ',
#                            'width': 3264}],
#                'place_id': 'ChIJ1WFE70PTD4gRV6y9PS1wiYk',
#                'plus_code': {'compound_code': 'W968+CW Chicago, Illinois',
#                              'global_code': '86HJW968+CW'},
#                'price_level': 2,
#                'rating': 3.9,
#                'reference': 'ChIJ1WFE70PTD4gRV6y9PS1wiYk',
#                'scope': 'GOOGLE',
#                'types': ['restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 116,
#                'vicinity': '129 W North Ave, Chicago'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 41.921933, 'lng': -87.64909},
#                             'viewport': {'northeast': {'lat': 41.92321702989272,
#                                                        'lng': -87.64773807010728},
#                                          'southwest': {'lat': 41.92051737010728,
#                                                        'lng': -87.65043772989273}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': 'Kameya',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 2448,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/105335399782835175406">A '
#                                                  'Google User</a>'],
#                            'photo_reference': 'Aap_uEDkrT3qwJgAHkqZADVt8XE1lDg2zgFsP1FcZXt6kY8DASjIbARQXgR4-TAYGuoz4JMEgR-XZAlfAqXviY4Sbv_YHdxLMmA9pA36RVWdglVUjduIeVhxDpfveOh6bIKFBOvNnP6zuQ9uuqkA841cR37mG3SDVGlPGoDNG72P5faCE3k',
#                            'width': 3264}],
#                'place_id': 'ChIJ6_JnbBrTD4gR47u8Y4Romfs',
#                'plus_code': {'compound_code': 'W9C2+Q9 Chicago, Illinois',
#                              'global_code': '86HJW9C2+Q9'},
#                'price_level': 2,
#                'rating': 4.6,
#                'reference': 'ChIJ6_JnbBrTD4gR47u8Y4Romfs',
#                'scope': 'GOOGLE',
#                'types': ['restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 133,
#                'vicinity': '806 W Webster Ave, Chicago'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 41.893954, 'lng': -87.628365},
#                             'viewport': {'northeast': {'lat': 41.89536647989272,
#                                                        'lng': -87.62701787010728},
#                                          'southwest': {'lat': 41.89266682010727,
#                                                        'lng': -87.62971752989272}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': 'True Food Kitchen',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 1896,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/108395418900714308669">True '
#                                                  'Food Kitchen</a>'],
#                            'photo_reference': 'Aap_uEDpu0lwC811_hb9EOOivwOGv3NnTdjdMhS9IZ4H8MqE9kx2AltaGXCAwkAWlHsb8Omocq57ZJZcZpHXIfXaS7y2PyEHgyj5WjsHTExn9TAZhjbifDItzWLCvgxDcwpF2hmhAFSZHQHLg_8yrePltoD-nyZyRVFRri4YotKZBX8Q9DZE',
#                            'width': 2532}],
#                'place_id': 'ChIJG4G-Ya0sDogRoHaQXnpcG74',
#                'plus_code': {'compound_code': 'V9VC+HM Chicago, Illinois',
#                              'global_code': '86HJV9VC+HM'},
#                'price_level': 2,
#                'rating': 4.5,
#                'reference': 'ChIJG4G-Ya0sDogRoHaQXnpcG74',
#                'scope': 'GOOGLE',
#                'types': ['restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 1547,
#                'vicinity': '1 W Erie St, Chicago'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 41.9200672, 'lng': -87.6366328},
#                             'viewport': {'northeast': {'lat': 41.92145897989272,
#                                                        'lng': -87.63526282010729},
#                                          'southwest': {'lat': 41.91875932010728,
#                                                        'lng': -87.63796247989272}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': 'R.J. Grunts',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 952,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/114269203759680150087">alonso '
#                                                  'bonilla</a>'],
#                            'photo_reference': 'Aap_uEAk1nWhDzLmjVREOdqlzrd2zwAiRZIbEp8mHc18PUbv1s2DiZs1P9ySBgnWYwDVRojLRLbRO1Mf90FY2d7pxmHdtRTCqOz9BT1kSnDvL8iLKiddByibQ-TEIgX7W_I_6qQ8Jevb3vrb6KktXz506F191wYavWCN6afwlRrawQCmpnvn',
#                            'width': 810}],
#                'place_id': 'ChIJ6a2WfGvTD4gRENVnPtP6xXc',
#                'plus_code': {'compound_code': 'W9C7+28 Chicago, Illinois',
#                              'global_code': '86HJW9C7+28'},
#                'price_level': 2,
#                'rating': 4.3,
#                'reference': 'ChIJ6a2WfGvTD4gRENVnPtP6xXc',
#                'scope': 'GOOGLE',
#                'types': ['bar',
#                          'restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 1663,
#                'vicinity': '2056 N Lincoln Park W, Chicago'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 41.9081724,
#                                          'lng': -87.67360289999999},
#                             'viewport': {'northeast': {'lat': 41.90944152989272,
#                                                        'lng': -87.67233017010727},
#                                          'southwest': {'lat': 41.90674187010728,
#                                                        'lng': -87.67502982989272}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': 'Taco Bell',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 600,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/107260337619016412188">Taco '
#                                                  'Bell</a>'],
#                            'photo_reference': 'Aap_uECYfLdOq3zndwtVzjAj7VrSMm7aRvAylmuIgVaZKaCLDMNcsspMdzIfCKPeDiArt3jRnYk7atSnAa5-vyZvmsTWKCVdHFHlSIOhONIfc-EW8VYaTK1wjrOOkV1DHKK4NovGA6em98LeptVTD-47fp6E1kPrl6yMNeXlcb1Nv4MHb5qH',
#                            'width': 600}],
#                'place_id': 'ChIJz4y4ZMbSD4gRE5nDWzQ-c1g',
#                'plus_code': {'compound_code': 'W85G+7H Chicago, Illinois',
#                              'global_code': '86HJW85G+7H'},
#                'price_level': 1,
#                'rating': 4.1,
#                'reference': 'ChIJz4y4ZMbSD4gRE5nDWzQ-c1g',
#                'scope': 'GOOGLE',
#                'types': ['meal_takeaway',
#                          'restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 1008,
#                'vicinity': '1439 N Milwaukee Ave, Chicago'}],
#   'status': 'OK'},
#  {'html_attributions': [],
#   'next_page_token': 'Aap_uEDjD2PrWYgDu79FdAbIPYMf9zaxPOxFrwJijN9TwmA2ldRqBv8au_DRPEknDv4TNQ8v5xuLdZirQcbKnPBgLJ0BCiuPBZ5rWMFthjI1rI1Ok4JOKGtIt2juChIR6jcjg9DkKB5LRRdffVI_bWsbhAAj5Ra-MFUl93TQbjHnNPNbLe4OcWg2QbiG_cgoJ4HWdZGGfdeB08UwimUxg5DaRCaoAvoQo0n4iiIImXowFuPBfIUxH1Ef0Un-YWNeztKJB2M0Ws3UAMu7qa4YPCg1z7bMFftNERuI-iwG_IufAuTEY20iHgPHdtI4l-jXVmFn3RE9vdIg4Fr8Eymc4IUtjcoCGD-svV-LBD2SDpopgtW6Md1AqrvpiCUxf9dKzDLkWq2V28ikMNzzyu-uTOdhzfvunurv4tIi3YA43WDmpvQV0PiLR13qro12wzq2f5TBtvXCQq-43AJDfnJFXvnAsLorecFZYWy3rxrUrQkOdt5v6s7NxnVpMENdKO7sEDSTvstB9hwIlN5OpAYY9mkmT3SppMPDyLPjpxxQoPzebBzX_pkcTo77MtK-E3D3ITgM2o0h8Q8vn8krU4SZhY-ByeReRIWuBO7j40d7zI8IZZtxf8kqd54KkZlCnrQYP7yStY5Tv92RPQ',
#   'results': [{'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 41.9221964,
#                                          'lng': -87.64458289999999},
#                             'viewport': {'northeast': {'lat': 41.92361212989272,
#                                                        'lng': -87.64314687010726},
#                                          'southwest': {'lat': 41.92091247010728,
#                                                        'lng': -87.64584652989271}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': "Xi'an Dynasty Cuisine 西安食代 (Lincoln Park)",
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 3024,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/117040788747065101824">Jianfeng '
#                                                  'Du</a>'],
#                            'photo_reference': 'Aap_uEDjNOxlFb9UrGLYOxHDGWcHRSUXv5Krpdk0YbK3EUmY97A2ZxikVH3Y94k3uYJy9U2YrOBBkbfAqDZXrKnjux5nsv0twcErN1AT5Bu8H9FD6CwXvac_3eAEk8xeIGMtgcwaQNCX-W3bJmxEOaaDXQUmTu9oxru3amK-43cDCf37Qo1f',
#                            'width': 4032}],
#                'place_id': 'ChIJb8C5k2jTD4gR7qwYAfywnPY',
#                'plus_code': {'compound_code': 'W9C4+V5 Chicago, Illinois',
#                              'global_code': '86HJW9C4+V5'},
#                'price_level': 1,
#                'rating': 4.7,
#                'reference': 'ChIJb8C5k2jTD4gR7qwYAfywnPY',
#                'scope': 'GOOGLE',
#                'types': ['restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 124,
#                'vicinity': '2218 N Lincoln Ave, Chicago'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 41.9237584, 'lng': -87.6686678},
#                             'viewport': {'northeast': {'lat': 41.92520882989272,
#                                                        'lng': -87.66728852010728},
#                                          'southwest': {'lat': 41.92250917010728,
#                                                        'lng': -87.66998817989273}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': "Wendy's",
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 720,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/114473675868787784396">Wendy&#39;s</a>'],
#                            'photo_reference': 'Aap_uECvnPAr9eMjNymky_PQ9OKHqwRND-AP3MaKpp9x-muidYGn9W2v81H_uQQfZu-vzBECiFtP8nx7zewq3C5LaEzfG7s8aDAOv5LdKAnbUHcuV2VOZuruBzumK1OIBVNtF_QT9kZR4tfZOhxCgc57arFgNXNQzrYU6hiyeG5zUdhRPT59',
#                            'width': 720}],
#                'place_id': 'ChIJ_24whu_SD4gRHteCQLI3ErE',
#                'plus_code': {'compound_code': 'W8FJ+GG Chicago, Illinois',
#                              'global_code': '86HJW8FJ+GG'},
#                'price_level': 1,
#                'rating': 3.9,
#                'reference': 'ChIJ_24whu_SD4gRHteCQLI3ErE',
#                'scope': 'GOOGLE',
#                'types': ['restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 1442,
#                'vicinity': '2312 N Ashland Ave, Chicago'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 41.9175694, 'lng': -87.648662},
#                             'viewport': {'northeast': {'lat': 41.91894427989272,
#                                                        'lng': -87.64722792010728},
#                                          'southwest': {'lat': 41.91624462010728,
#                                                        'lng': -87.64992757989273}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': 'Summer House Santa Monica',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 2400,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/110633615553284940915">A '
#                                                  'Google User</a>'],
#                            'photo_reference': 'Aap_uEBso5fQpryLD8VJbIkTyWNofw7A41RzpS6oxIwLcFukCOZuNSM_OSPmZWrIoyFxzrvdijPFG54mk4L6j4XlUJah__VvLls3qWm1SnAMIcVWtcnRLx6dBS3xwTzny-6vYQCGcujhQmXb5mXPTfD_RZdPx4e5ZEPHGdHR84YIrLuqN_Jo',
#                            'width': 1600}],
#                'place_id': 'ChIJxYDpLhjTD4gRXbOM_K_279E',
#                'plus_code': {'compound_code': 'W992+2G Chicago, Illinois',
#                              'global_code': '86HJW992+2G'},
#                'price_level': 2,
#                'rating': 4.4,
#                'reference': 'ChIJxYDpLhjTD4gRXbOM_K_279E',
#                'scope': 'GOOGLE',
#                'types': ['bakery',
#                          'bar',
#                          'restaurant',
#                          'food',
#                          'point_of_interest',
#                          'store',
# ...
#                          'establishment'],
#                'user_ratings_total': 931,
#                'vicinity': '5189 Baum Blvd, Pittsburgh'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 40.8968287,
#                                          'lng': -79.90743719999999},
#                             'viewport': {'northeast': {'lat': 40.89815052989272,
#                                                        'lng': -79.90616952010727},
#                                          'southwest': {'lat': 40.89545087010728,
#                                                        'lng': -79.90886917989272}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': "Wendy's",
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 720,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/111698418587770754933">Wendy&#39;s</a>'],
#                            'photo_reference': 'Aap_uEAndTlISiaoqMLNJQVNI0msZx1tems6VPUFjlE2v04KBVUhqHR4e-vr8qaHkYWoKUFQiKp1bSg_YuANjEd9S-4PuGHGtsSaC4g93DzamaS8qKHv6Qjs2ZzkQmVutA9iGg22lkzeWJQ8TEpbF0wPbEMp8RsuqZpXXfeE3JEJVBJ7rt-y',
#                            'width': 720}],
#                'place_id': 'ChIJv_WhJDhjM4gR2uEn8P9Vaig',
#                'plus_code': {'compound_code': 'V3WV+P2 Butler, Pennsylvania',
#                              'global_code': '87G2V3WV+P2'},
#                'price_level': 1,
#                'rating': 4.1,
#                'reference': 'ChIJv_WhJDhjM4gR2uEn8P9Vaig',
#                'scope': 'GOOGLE',
#                'types': ['restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 480,
#                'vicinity': '122 Clearview Cir, Butler'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 40.4535141, 'lng': -80.1577178},
#                             'viewport': {'northeast': {'lat': 40.45453472989272,
#                                                        'lng': -80.15584537010727},
#                                          'southwest': {'lat': 40.45183507010727,
#                                                        'lng': -80.15854502989272}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': 'Chick-fil-A',
#                'opening_hours': {'open_now': False},
#                'photos': [{'height': 288,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/114576939771179607152">Chick-fil-A</a>'],
#                            'photo_reference': 'Aap_uECCLRUr2D7eMWI9U7eitrc0HwoZ2UDyrRGsn_4JEYE1kb4PD16VwGMm-Rx2R07TshBsRYP4MNpE8NeqvMGf0LbAk5UrTxKe9caZ-jIIcJFgLGi3SELdujctH81QG80BnuQ0jfTiro0gwEVTPQ_HYkiDAjYxpA179eVHn9moLyuM5PAi',
#                            'width': 512}],
#                'place_id': 'ChIJd51DBeFYNIgRF6Zp63YbC_c',
#                'plus_code': {'compound_code': 'FR3R+CW Pittsburgh, '
#                                               'Pennsylvania',
#                              'global_code': '86GXFR3R+CW'},
#                'price_level': 1,
#                'rating': 4.4,
#                'reference': 'ChIJd51DBeFYNIgRF6Zp63YbC_c',
#                'scope': 'GOOGLE',
#                'types': ['restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 779,
#                'vicinity': '100 Robinson Centre Dr # FC - 5, Pittsburgh'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 40.43659100000001,
#                                          'lng': -79.99061619999999},
#                             'viewport': {'northeast': {'lat': 40.43810622989272,
#                                                        'lng': -79.98935277010726},
#                                          'southwest': {'lat': 40.43540657010728,
#                                                        'lng': -79.99205242989271}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': 'Chick-fil-A',
#                'opening_hours': {'open_now': False},
#                'place_id': 'ChIJd_gIZlzxNIgRi2DeYXpiNmA',
#                'plus_code': {'compound_code': 'C2P5+JQ Pittsburgh, '
#                                               'Pennsylvania',
#                              'global_code': '87G2C2P5+JQ'},
#                'price_level': 1,
#                'rating': 3.9,
#                'reference': 'ChIJd_gIZlzxNIgRi2DeYXpiNmA',
#                'scope': 'GOOGLE',
#                'types': ['restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 56,
#                'vicinity': '600 Forbes Ave, Pittsburgh'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 40.41270919999999,
#                                          'lng': -79.9078818},
#                             'viewport': {'northeast': {'lat': 40.41413162989272,
#                                                        'lng': -79.90646017010728},
#                                          'southwest': {'lat': 40.41143197010727,
#                                                        'lng': -79.90915982989272}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': 'Chick-fil-A',
#                'opening_hours': {'open_now': False},
#                'photos': [{'height': 2988,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/104800014087143737890">Ross '
#                                                  'Fulton</a>'],
#                            'photo_reference': 'Aap_uEDTpjTgGs6kBV5GMjpFhhYCwYdNO1sdHsRlyDA2Ci5psbpDxSWPt67E4LoTjX5W8ONkx-HHyvdSIj73ta2K5vsyuGRuec7_JPh-7SuwUNORjoW5tyX9IGNg5FCglV-UqezZgmbaDErCpmOIkn-yCzJyK-oG90BQ6-r7o3ZdazNZ1D5i',
#                            'width': 5312}],
#                'place_id': 'ChIJz-_0zDzuNIgRTAb9TlhSk7Q',
#                'plus_code': {'compound_code': 'C37R+3R Homestead, Pennsylvania',
#                              'global_code': '87G2C37R+3R'},
#                'price_level': 1,
#                'rating': 4.6,
#                'reference': 'ChIJz-_0zDzuNIgRTAb9TlhSk7Q',
#                'scope': 'GOOGLE',
#                'types': ['restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 1981,
#                'vicinity': '480 E Waterfront Dr, Homestead'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 40.8557823,
#                                          'lng': -79.90955029999999},
#                             'viewport': {'northeast': {'lat': 40.85704247989272,
#                                                        'lng': -79.90825947010728},
#                                          'southwest': {'lat': 40.85434282010728,
#                                                        'lng': -79.91095912989273}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': "Arby's",
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 583,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/101875784868850638515">Arby&#39;s</a>'],
#                            'photo_reference': 'Aap_uEASvu1V--6iLg0QXWYlgWZ-HnRI7sBPjWah9ResZLaFzj_GPxWYWw3aAHE3ECTMoDwDTupbxhMKE6csOf33Sg-DQDmEYH1fuHLdyp9VrMYY9PncLPlyXk_hVw0l34TOKoKumJph2nMNUBvbxPBr9zxvNqQqIrjaiQqkz9i-UQhBEmVr',
#                            'width': 1114}],
#                'place_id': 'ChIJR-nQu7diM4gReWb7c4iQYiU',
#                'plus_code': {'compound_code': 'V34R+85 Butler, Pennsylvania',
#                              'global_code': '87G2V34R+85'},
#                'price_level': 1,
#                'rating': 4,
#                'reference': 'ChIJR-nQu7diM4gReWb7c4iQYiU',
#                'scope': 'GOOGLE',
#                'types': ['meal_takeaway',
#                          'restaurant',
#                          'food',
#                          'point_of_interest',
#                          'store',
#                          'establishment'],
#                'user_ratings_total': 372,
#                'vicinity': '100 CDC Dr, Butler'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 40.3066758, 'lng': -79.5801343},
#                             'viewport': {'northeast': {'lat': 40.30802937989272,
#                                                        'lng': -79.57873592010726},
#                                          'southwest': {'lat': 40.30532972010727,
#                                                        'lng': -79.58143557989271}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': 'Chick-fil-A',
#                'opening_hours': {'open_now': False},
#                'photos': [{'height': 288,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/111823385771379781364">Chick-fil-A</a>'],
#                            'photo_reference': 'Aap_uEBMS_fIzhLDpjqeUzhE_PO3cqHs4c3r9kIPxBG7MjKVDb7ja8t1vkvuf52217X34bSXaBX52J3-4bhpsufBE0UVUBpSwD1J-Tw1-pQ8n5gZNFL3yMTt035vIJFNoBY_AgswXyPVaS483rXu3xvdbobRo_RrvStZPi-_t13E75M8ImNo',
#                            'width': 512}],
#                'place_id': 'ChIJne6xK77aNIgRAxKIYjyjVyY',
#                'plus_code': {'compound_code': '8C49+MW Greensburg, '
#                                               'Pennsylvania',
#                              'global_code': '87G28C49+MW'},
#                'price_level': 1,
#                'rating': 4.7,
#                'reference': 'ChIJne6xK77aNIgRAxKIYjyjVyY',
#                'scope': 'GOOGLE',
#                'types': ['restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 1806,
#                'vicinity': '900 Greengate Centre Cir, Greensburg'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 40.45071919999999,
#                                          'lng': -79.9855114},
#                             'viewport': {'northeast': {'lat': 40.45211857989273,
#                                                        'lng': -79.98414522010728},
#                                          'southwest': {'lat': 40.44941892010728,
#                                                        'lng': -79.98684487989271}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/bar_pinlet',
#                'name': 'Primanti Bros. Restaurant and Bar Strip District',
#                'opening_hours': {'open_now': True},
#                'photos': [{'height': 1960,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/108609857417087425686">Keith '
#                                                  'Rench</a>'],
#                            'photo_reference': 'Aap_uECCyY_aH0pe3oOnISTORJ5w1HQPK6xnE-uSWEp5LxtDJPwwZahiDuOfoNl17I_A7LQ-DZfreo_LKkYTVbsjfUAdxxVGsEu7BuR2107d03qEdswGZHHA9-uKs4MwLlIaOtvOH8MNNYKWHI8Jvj-KMJzPSdrXwBTWq78iAAphMzokpgFx',
#                            'width': 4032}],
#                'place_id': 'ChIJldAGdt3zNIgRjGeERIxAoAE',
#                'plus_code': {'compound_code': 'F227+7Q Pittsburgh, '
#                                               'Pennsylvania',
#                              'global_code': '87G2F227+7Q'},
#                'price_level': 1,
#                'rating': 4.5,
#                'reference': 'ChIJldAGdt3zNIgRjGeERIxAoAE',
#                'scope': 'GOOGLE',
#                'types': ['bar',
#                          'restaurant',
#                          'food',
#                          'point_of_interest',
#                          'establishment'],
#                'user_ratings_total': 5049,
#                'vicinity': '46 18th St, Pittsburgh'},
#               {'business_status': 'OPERATIONAL',
#                'geometry': {'location': {'lat': 40.67259, 'lng': -80.0991682},
#                             'viewport': {'northeast': {'lat': 40.67389277989273,
#                                                        'lng': -80.09781602010729},
#                                          'southwest': {'lat': 40.67119312010728,
#                                                        'lng': -80.10051567989272}}},
#                'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#                'icon_background_color': '#FF9E67',
#                'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#                'name': "Arby's",
#                'opening_hours': {'open_now': False},
#                'photos': [{'height': 583,
#                            'html_attributions': ['<a '
#                                                  'href="https://maps.google.com/maps/contrib/109660278847198426201">Arby&#39;s</a>'],
#                            'photo_reference': 'Aap_uEDhZUnnM0tc4hCKEdkZux7G8otYqAN_J6ndoOL2DPNtBBCQ8EivjnQxjXGIpFb4iyT4iWg9HETnyjd1PSPBc0GtzSAMgV5YGR-40-vtvsQrHrVzRaHPk7Bp5VmbCPsDrXodJDsIjH54dCYpvI3eGS2jlH-J9uNgwNChe32XmwH4MIRv',
#                            'width': 1114}],
#                'place_id': 'ChIJP9YR2Z9iNIgRwKPYijx-nP4',
#                'plus_code': {'compound_code': 'MWF2+28 Seven Fields, '
#                                               'Pennsylvania',
#                              'global_code': '86GXMWF2+28'},
#                'price_level': 1,
#                'rating': 4.1,
#                'reference': 'ChIJP9YR2Z9iNIgRwKPYijx-nP4',
#                'scope': 'GOOGLE',
#                'types': ['meal_takeaway',
#                          'restaurant',
#                          'food',
#                          'point_of_interest',
#                          'store',
#                          'establishment'],
#                'user_ratings_total': 808,
#                'vicinity': '19075 Perry Hwy, Seven Fields'}],
#   'status': 'OK'}]

# %%
# Taking the lists and utilizing the json_normalize function to convert each json page into a dataframe

chicago_df = pd.json_normalize(chicago_data[0], record_path=["results"])
chicago_df = chicago_df[["name", "business_status", "rating", "price_level", "types", "vicinity", "geometry.location.lat", "geometry.location.lng"]]
chicago_df
#------------------------------------------------------------------------------------------#
oley_df = pd.json_normalize(oley_data[0], record_path=["results"])
oley_df = oley_df[["name", "business_status", "rating", "price_level", "types", "vicinity", "geometry.location.lat", "geometry.location.lng"]]
#oley_df
#------------------------------------------------------------------------------------------#
beth_df = pd.json_normalize(beth_data[0], record_path=["results"])
beth_df = beth_df[["name", "business_status", "rating", "price_level", "types", "vicinity", "geometry.location.lat", "geometry.location.lng"]]
#beth_df
#------------------------------------------------------------------------------------------#
horsham_df = pd.json_normalize(horsham_data[0], record_path=["results"])
horsham_df = horsham_df[["name", "business_status", "rating", "price_level", "types", "vicinity", "geometry.location.lat", "geometry.location.lng"]]
#horsham_df
#------------------------------------------------------------------------------------------#
north_philly_df = pd.json_normalize(north_philly_data[0], record_path=["results"])
north_philly_df = north_philly_df[["name", "business_status", "rating", "price_level", "types", "vicinity", "geometry.location.lat", "geometry.location.lng"]]
#north_philly_df
#------------------------------------------------------------------------------------------#
pitts_df = pd.json_normalize(pitts_data[0], record_path=["results"])
pitts_df = pitts_df[["name", "business_status", "rating", "price_level", "types", "vicinity", "geometry.location.lat", "geometry.location.lng"]]
pitts_df
# Out:
#                                                 name business_status  rating  \
# 0                       Proper Brick Oven & Tap Room     OPERATIONAL     4.6
# 1                                        Chick-fil-A     OPERATIONAL     4.6
# 2                                            Mad Mex     OPERATIONAL     4.2
# 3                                        Chick-fil-A     OPERATIONAL     4.5
# 4                                             Arby's     OPERATIONAL     4.0
# ..                                               ...             ...     ...
# 75                                       Chick-fil-A     OPERATIONAL     4.6
# 76                                            Arby's     OPERATIONAL     4.0
# 77                                       Chick-fil-A     OPERATIONAL     4.7
# 78  Primanti Bros. Restaurant and Bar Strip District     OPERATIONAL     4.5
# 79                                            Arby's     OPERATIONAL     4.1
#
#     price_level                                              types  \
# 0             2  [bar, restaurant, food, point_of_interest, est...
# 1             1  [restaurant, food, point_of_interest, establis...
# 2             2  [restaurant, food, point_of_interest, establis...
# 3             1  [restaurant, food, point_of_interest, establis...
# 4             1  [meal_takeaway, restaurant, food, point_of_int...
# ..          ...                                                ...
# 75            1  [restaurant, food, point_of_interest, establis...
# 76            1  [meal_takeaway, restaurant, food, point_of_int...
# 77            1  [restaurant, food, point_of_interest, establis...
# 78            1  [bar, restaurant, food, point_of_interest, est...
# 79            1  [meal_takeaway, restaurant, food, point_of_int...
#
#                                 vicinity  geometry.location.lat  \
# 0                 139 7th St, Pittsburgh              40.443553
# 1           7451 McKnight Rd, Pittsburgh              40.540780
# 2          2101 Greentree Rd, Pittsburgh              40.390556
# 3              120 Andrew Dr, Pittsburgh              40.451051
# 4            808 Liberty Ave, Pittsburgh              40.442575
# ..                                   ...                    ...
# 75        480 E Waterfront Dr, Homestead              40.412709
# 76                    100 CDC Dr, Butler              40.855782
# 77  900 Greengate Centre Cir, Greensburg              40.306676
# 78                46 18th St, Pittsburgh              40.450719
# 79         19075 Perry Hwy, Seven Fields              40.672590
#
#     geometry.location.lng
# 0              -80.000219
# 1              -80.013000
# 2              -80.072500
# 3              -80.175018
# 4              -79.998718
# ..                    ...
# 75             -79.907882
# 76             -79.909550
# 77             -79.580134
# 78             -79.985511
# 79             -80.099168
#
# [80 rows x 8 columns]

# %%
# Concatenating all data entries into a single dataframe to prepare for exportation

all = [chicago_df, oley_df, beth_df, horsham_df, north_philly_df, pitts_df]
all_df = pd.concat(all)
all_df.rename(columns = {'geometry.location.lat':'Latitude', 'geometry.location.lng':'Longitude'}, inplace = True)
all_df
# Out:
#                                                 name business_status  rating  \
# 0          Xi'an Dynasty Cuisine 西安食代 (Lincoln Park)     OPERATIONAL     4.7
# 1                                            Wendy's     OPERATIONAL     3.9
# 2                          Summer House Santa Monica     OPERATIONAL     4.4
# 3                                       Kizami Sushi     OPERATIONAL     4.8
# 4                                           Dog Haus     OPERATIONAL     4.4
# ..                                               ...             ...     ...
# 75                                       Chick-fil-A     OPERATIONAL     4.6
# 76                                            Arby's     OPERATIONAL     4.0
# 77                                       Chick-fil-A     OPERATIONAL     4.7
# 78  Primanti Bros. Restaurant and Bar Strip District     OPERATIONAL     4.5
# 79                                            Arby's     OPERATIONAL     4.1
#
#     price_level                                              types  \
# 0           1.0  [restaurant, food, point_of_interest, establis...
# 1           1.0  [restaurant, food, point_of_interest, establis...
# 2           2.0  [bakery, bar, restaurant, food, point_of_inter...
# 3           2.0  [restaurant, food, point_of_interest, establis...
# 4           2.0  [meal_takeaway, bar, restaurant, food, point_o...
# ..          ...                                                ...
# 75          1.0  [restaurant, food, point_of_interest, establis...
# 76          1.0  [meal_takeaway, restaurant, food, point_of_int...
# 77          1.0  [restaurant, food, point_of_interest, establis...
# 78          1.0  [bar, restaurant, food, point_of_interest, est...
# 79          1.0  [meal_takeaway, restaurant, food, point_of_int...
#
#                                 vicinity   Latitude  Longitude
# 0            2218 N Lincoln Ave, Chicago  41.922196 -87.644583
# 1            2312 N Ashland Ave, Chicago  41.923758 -87.668668
# 2             1954 N Halsted St, Chicago  41.917569 -87.648662
# 3            2235 N Lincoln Ave, Chicago  41.922811 -87.644866
# 4            2464 N Lincoln Ave, Chicago  41.926745 -87.650976
# ..                                   ...        ...        ...
# 75        480 E Waterfront Dr, Homestead  40.412709 -79.907882
# 76                    100 CDC Dr, Butler  40.855782 -79.909550
# 77  900 Greengate Centre Cir, Greensburg  40.306676 -79.580134
# 78                46 18th St, Pittsburgh  40.450719 -79.985511
# 79         19075 Perry Hwy, Seven Fields  40.672590 -80.099168
#
# [880 rows x 8 columns]

# %%
# Exporting dataframe with all entries to a csv file for implementation in Tableau

all_df.to_csv(path_or_buf="establishment_data")
